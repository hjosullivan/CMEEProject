# %% [markdown]
# # Data Wrangling for TPC data

# %% [markdown]
# Hannah O'Sullivan h.osullivan18@imperial.ac.uk

# %% [markdown]
# *The pandas friendly approach*

# %% [markdown]
# `code block`

# %% [markdown]
# ## Hello world

# %% [markdown]
# As Kanye West said:
#
# > We're living the future so
# > the present is our past.

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame(np.random.randn(10,15))
df
# Out:
#          0         1         2         3         4         5         6   \
# 0 -0.264503 -1.122660 -0.355993 -1.047050  0.905543 -0.353399 -1.424085
# 1 -0.535461  0.304668 -1.421518  0.781989 -0.557922 -0.033081 -0.825016
# 2 -0.683207  0.514288 -0.507414  0.394417 -0.231154  0.102317 -1.090905
# 3 -0.841592 -0.443634 -0.380412  0.728990  0.479033  1.256389  0.056034
# 4  0.756408  1.284605  1.393187 -1.270348 -1.407390 -0.890297  0.616382
# 5  0.739057 -1.395276  0.402915  0.119944 -0.539356 -0.225615 -0.463222
# 6  1.721821 -0.734629 -0.862489 -0.451123  0.953973 -0.160700 -1.018441
# 7 -0.266381  0.794586 -0.867928 -0.565131 -0.998312  0.851269 -0.930777
# 8  0.254477 -0.841316 -1.566158  0.455786  0.310337  1.336559  0.837099
# 9  0.843327  0.011926  0.606422 -0.162741 -1.808463  0.034189  0.133167
#
#          7         8         9         10        11        12        13  \
# 0 -0.268884  0.550430 -0.861465  1.086551  0.075980 -0.282355  0.178568
# ...
